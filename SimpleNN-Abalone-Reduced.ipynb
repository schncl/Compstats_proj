# %%
seed=42
import numpy as np
import logging
import seaborn as sns
import matplotlib as mpl
import pandas as pd
np.random.seed(42)
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.random.set_seed(seed)
print(f"TensorFlow version {tf.__version__}")
# Out:
# TensorFlow version 2.18.0

# %%
train_data=np.loadtxt("/content/drive/MyDrive/Compstat_SimpleNN/data/Abalone/train_reduced.txt")
test_data=np.loadtxt("/content/drive/MyDrive/Compstat_SimpleNN/data/Abalone/test.txt")

# %%
x_data = train_data[:,:-1]
y_data = train_data[:,-1]
X_test = test_data[:,:-1]
y_test = test_data[:,-1]

# %%
X_train, X_val, y_train, y_val = train_test_split(
    x_data,
    y_data,
    test_size = 0.1, # Ensure validation set size matches test set size
    random_state=42
)

# %%
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((1578, 8), (176, 8), (1578,), (176,))

# %%
max_df=X_train.max()
max_target=y_train.max()
min_df=X_train.min()
min_target=y_train.min()

# %%
X_train = (X_train - min_df)/(max_df - min_df)
X_val = (X_val - min_df)/(max_df - min_df)
X_test = (X_test - min_df)/(max_df - min_df)


y_train = (y_train - min_target)/(max_target - min_target)
y_val = (y_val - min_target)/(max_target - min_target)
y_test = (y_test - min_target)/(max_target - min_target)

# %%
# Define a function for plotting training and validation Mean Squared Error (MSE) histories.
def plot_histories(metadata, training=False, baseline=False, show_all=False):

    print('VALIDATION MSE')
    plt.figure(figsize=(21, 9))

    # Iterate through different models stored in metadata.
    for model in list(metadata.keys()):

        # Skip the baseline model if baseline flag is False.
        if model == 'Baseline' and not baseline:
            continue

        # Retrieve relevant information from the metadata dictionary.
        history = metadata[model]['history']
        patience = metadata[model]['patience']
        color = metadata[model]['color']
        val_score = metadata[model]['val_score']
        print('%s: %.4f' % (model, val_score))

        # Plot training and validation MSE histories with or without patience handling.
        if patience != 0:
            if training:
                plt.plot(
                    history['mse'][:-patience],
                    alpha=0.5,
                    color=color
                )
                if show_all:
                    plt.plot(
                        np.arange(len(history['mse']) - patience - 1, len(history['mse'])),
                        history['mse'][-patience - 1:],
                        alpha=0.2,
                        color=color
                    )

            plt.plot(
                history['val_mse'][:-patience],
                label=model,
                alpha=0.9,
                color=color
            )
            if show_all:
                plt.plot(
                    np.arange(len(history['val_mse']) - patience - 1, len(history['val_mse'])),
                    history['val_mse'][-patience - 1:],
                    alpha=0.2,
                    color=color
                )

        else:
            if training:
                plt.plot(
                    history['mse'],
                    alpha=0.5,
                    color=color
                )
            plt.plot(
                history['val_mse'],
                label=model,
                alpha=0.9,
                color=color
            )

        # Set y-axis limits and add labels, legends, and grid.
        if training:
            plt.ylim(0.004, 0.0225)
        else:
            plt.ylim(0.01, 0.025)
        plt.title('Mean Squared Error')
        plt.legend(loc='upper right')
        plt.grid(alpha=0.3)

    # Display the plot.
    plt.show()

# %%
'''
# Define a function for plotting residuals and model predictions
def plot_residuals(model, data, labels):
    # Sort the data and labels based on the 'labels' column
    data['sort'] = labels
    data = data.sort_values(by=['sort'])
    labels = np.expand_dims(data['sort'], 1)
    data.drop(['sort'], axis=1, inplace=True)

    # Make predictions using the model
    y_pred = model.predict(data, verbose=0)

    # Calculate squared errors and mean squared error (MSE)
    squared_errors = (labels - y_pred)**2
    mse = np.mean(squared_errors).astype('float32')
    print('MSE: %.4f' % mse)

    # Set up plotting styles and create a scatter plot
    mpl.rcParams.update(mpl.rcParamsDefault)
    sns.set(font_scale=1.1, style=None, palette='Set1')
    plt.figure(figsize=(21, 5))

    # Plot true labels in red and model predictions in blue
    plt.scatter(np.arange(len(labels)), labels, label='True', color='#d62728', alpha=0.7, s=8)

    # Add vertical lines to represent residuals
    for i in range(len(labels)):
        if labels[i] >= y_pred[i]:
            plt.vlines(i, y_pred[i], labels[i], alpha=0.2, linewidth=0.5)
        else:
            plt.vlines(i, labels[i], y_pred[i], alpha=0.2, linewidth=0.5)

    plt.scatter(np.arange(len(y_pred)), y_pred, label='Prediction', color='#1f77b4', s=8)

    # Add legends, grid, and set y-axis limits
    plt.legend()
    plt.grid(alpha=0.3)
    plt.ylim((-0.1, 1.1))
    plt.show()
    '''
# Out:
# "\n# Define a function for plotting residuals and model predictions\ndef plot_residuals(model, data, labels):\n    # Sort the data and labels based on the 'labels' column\n    data['sort'] = labels\n    data = data.sort_values(by=['sort'])\n    labels = np.expand_dims(data['sort'], 1)\n    data.drop(['sort'], axis=1, inplace=True)\n\n    # Make predictions using the model\n    y_pred = model.predict(data, verbose=0)\n\n    # Calculate squared errors and mean squared error (MSE)\n    squared_errors = (labels - y_pred)**2\n    mse = np.mean(squared_errors).astype('float32')\n    print('MSE: %.4f' % mse)\n\n    # Set up plotting styles and create a scatter plot\n    mpl.rcParams.update(mpl.rcParamsDefault)\n    sns.set(font_scale=1.1, style=None, palette='Set1')\n    plt.figure(figsize=(21, 5))\n\n    # Plot true labels in red and model predictions in blue\n    plt.scatter(np.arange(len(labels)), labels, label='True', color='#d62728', alpha=0.7, s=8)\n\n    # Add vertical lines to represent residuals\n    for i in range(len(labels)):\n        if labels[i] >= y_pred[i]:\n            plt.vlines(i, y_pred[i], labels[i], alpha=0.2, linewidth=0.5)\n        else:\n            plt.vlines(i, labels[i], y_pred[i], alpha=0.2, linewidth=0.5)\n\n    plt.scatter(np.arange(len(y_pred)), y_pred, label='Prediction', color='#1f77b4', s=8)\n\n    # Add legends, grid, and set y-axis limits\n    plt.legend()\n    plt.grid(alpha=0.3)\n    plt.ylim((-0.1, 1.1))\n    plt.show()\n    "

# %%
def plot_residuals(model, x_train, y_train):
    # Sort x_train and y_train based on y_train values
    sorted_indices = np.argsort(y_train, axis=0).flatten()
    x_sorted = x_train[sorted_indices]
    y_sorted = y_train[sorted_indices]

    # Make predictions using the model
    y_pred = model.predict(x_sorted, verbose=0)

    # Ensure y arrays are 1D for calculations and plotting
    y_sorted = y_sorted.squeeze()
    y_pred = y_pred.squeeze()

    # Calculate squared errors and MSE
    squared_errors = (y_sorted - y_pred) ** 2
    mse = np.mean(squared_errors).astype('float32')
    print('MSE: %.4f' % mse)

    # Set up plotting
    mpl.rcParams.update(mpl.rcParamsDefault)
    sns.set(font_scale=1.1, style=None, palette='Set1')
    plt.figure(figsize=(21, 5))

    # Plot true values
    plt.scatter(np.arange(len(y_sorted)), y_sorted,
                label='True', color='#d62728', alpha=0.7, s=8)

    # Add vertical residual lines
    for i in range(len(y_sorted)):
        if y_sorted[i] >= y_pred[i]:
            plt.vlines(i, y_pred[i], y_sorted[i],
                      alpha=0.2, linewidth=0.5)
        else:
            plt.vlines(i, y_sorted[i], y_pred[i],
                      alpha=0.2, linewidth=0.5)

    # Plot predicted values
    plt.scatter(np.arange(len(y_pred)), y_pred,
                label='Prediction', color='#1f77b4', s=8)

    # Configure plot
    plt.legend()
    plt.grid(alpha=0.3)
    plt.ylim((-0.1, 1.1))
    plt.show()

# %%
def evaluate_and_plot_model(model, X_val, y_val, X_test, y_test, metadata, history, patience, model_name, color, plot_baseline=False):
    # Calculate validation Mean Squared Error (MSE) for the model
    val_predictions = np.squeeze(model.predict(X_val, verbose=0))
    val_squared_errors = (y_val - val_predictions)**2
    val_mse = np.mean(val_squared_errors).astype('float32')

    # Calculate test Mean Squared Error (MSE) for the model
    test_predictions = np.squeeze(model.predict(X_test, verbose=0))
    test_squared_errors = (y_test - test_predictions)**2
    test_mse = np.mean(test_squared_errors).astype('float32')

    # Add model metadata to the dictionary
    metadata[model_name] = {
        'model': model,
        'history': history,
        'color': color,
        'patience': patience,
        'val_score': val_mse,
        'test_score': test_mse
    }

    # Plot histories
    plot_histories(metadata, baseline=plot_baseline)

    return metadata

# %%
def build_model(input_shape, learning_rate=1e-3, name='', seed=seed):

    # Set random seed for reproducibility
    tf.random.set_seed(seed)

    # Initialise weights and regulariser
    initialiser = tfk.initializers.GlorotNormal(seed=seed)
    # Input layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')
    # Hidden layers with ReLU activations
    x = tfkl.Dense(units=10, name='HiddenDense1', kernel_initializer=initialiser)(input_layer)
    x = tfkl.Activation('sigmoid', name='HiddenActivation1')(x)

    output_layer = tfkl.Dense(units=1, kernel_initializer=initialiser, name='Output')(x)

    # Linear output activation
    output_activation = tfkl.Activation('linear', name='OutputActivation')(output_layer)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_activation, name=name)

    # Compile the model with Adam optimiser and MSE loss
    opt = tfk.optimizers.Adam(learning_rate)
    loss = tfk.losses.MeanSquaredError()
    mtr = ['mse']
    model.compile(loss=loss, optimizer=opt, metrics=mtr)

    # Return the compiled model
    return model

# %%
input_shape = X_train.shape[1:]

# Define the batch size for training
batch_size = 64

# Define the number of training epochs
epochs = 500

# Create an empty dictionary to store metadata
metadata = {}

# %%
model = build_model(input_shape)
model.summary(expand_nested=True, show_trainable=True)
tfk.utils.plot_model(model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Model: ""
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Layer (type)                        ┃ Output Shape                 ┃       Param # ┃ Traina… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ Input (InputLayer)                  │ (None, 8)                    │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ HiddenDense1 (Dense)                │ (None, 10)                   │            90 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ HiddenActivation1 (Activation)      │ (None, 10)                   │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ Output (Dense)                      │ (None, 1)                    │            11 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ OutputActivation (Activation)       │ (None, 1)                    │             0 │    -    │
# └─────────────────────────────────────┴──────────────────────────────┴───────────────┴─────────┘
#  Total params: 101 (404.00 B)
#  Trainable params: 101 (404.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    x = X_train,
    y = y_train,
    validation_data = (X_val, y_val),
    batch_size = batch_size,
    epochs = epochs,
    verbose=1
).history
# Out:
# Epoch 1/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0316 - mse: 0.0316 - val_loss: 0.0295 - val_mse: 0.0295
# Epoch 2/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0227 - mse: 0.0227 - val_loss: 0.0266 - val_mse: 0.0266
# Epoch 3/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0208 - mse: 0.0208 - val_loss: 0.0249 - val_mse: 0.0249
# Epoch 4/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0191 - mse: 0.0191 - val_loss: 0.0233 - val_mse: 0.0233
# Epoch 5/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0178 - mse: 0.0178 - val_loss: 0.0219 - val_mse: 0.0219
# Epoch 6/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0166 - mse: 0.0166 - val_loss: 0.0207 - val_mse: 0.0207
# Epoch 7/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0197 - val_mse: 0.0197
# Epoch 8/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0188 - val_mse: 0.0188
# Epoch 9/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 10/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0174 - val_mse: 0.0174
# Epoch 11/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0169 - val_mse: 0.0169
# Epoch 12/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0165 - val_mse: 0.0165
# Epoch 13/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0161 - val_mse: 0.0161
# Epoch 14/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0158 - val_mse: 0.0158
# Epoch 15/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0156 - val_mse: 0.0156
# Epoch 16/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0154 - val_mse: 0.0154
# Epoch 17/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0152 - val_mse: 0.0152
# Epoch 18/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0150 - val_mse: 0.0150
# Epoch 19/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0149 - val_mse: 0.0149
# Epoch 20/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0148 - val_mse: 0.0148
# Epoch 21/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0146 - val_mse: 0.0146
# Epoch 22/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0145 - val_mse: 0.0145
# Epoch 23/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0144 - val_mse: 0.0144
# Epoch 24/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0143 - val_mse: 0.0143
# Epoch 25/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 26/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0141 - val_mse: 0.0141
# Epoch 27/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 28/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 29/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0139 - val_mse: 0.0139
# Epoch 30/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0138 - val_mse: 0.0138
# Epoch 31/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 32/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 33/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 34/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 35/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 36/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 37/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 38/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 39/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0132 - val_mse: 0.0132
# Epoch 40/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0132 - val_mse: 0.0132
# Epoch 41/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0131 - val_mse: 0.0131
# Epoch 42/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0131 - val_mse: 0.0131
# Epoch 43/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0130 - val_mse: 0.0130
# Epoch 44/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0130 - val_mse: 0.0130
# Epoch 45/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 46/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 47/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0128 - val_mse: 0.0128
# Epoch 48/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0128 - val_mse: 0.0128
# Epoch 49/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0127 - val_mse: 0.0127
# Epoch 50/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0127 - val_mse: 0.0127
# Epoch 51/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 52/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 53/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 54/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 55/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 56/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 57/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 58/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0123 - val_mse: 0.0123
# Epoch 59/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0123 - val_mse: 0.0123
# Epoch 60/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0122 - val_mse: 0.0122
# Epoch 61/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0122 - val_mse: 0.0122
# Epoch 62/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 63/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 64/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 65/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0120 - val_mse: 0.0120
# Epoch 66/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0120 - val_mse: 0.0120
# Epoch 67/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 68/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 69/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 70/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 71/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 72/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 73/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 74/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 75/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 76/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 77/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 78/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 79/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 80/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 81/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 82/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 83/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 84/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 85/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 86/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 87/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 88/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 89/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 90/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 91/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 92/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 93/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 94/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 95/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 96/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 97/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 98/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 99/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 100/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 101/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 102/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 103/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 104/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 105/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 106/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 107/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 108/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 109/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 110/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 111/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 112/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 113/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 114/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 115/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 116/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 117/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 118/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 119/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 120/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 121/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 122/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 123/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 124/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 125/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 126/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 127/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 128/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 129/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 130/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 131/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 132/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 133/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 134/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 135/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 136/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 137/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 138/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 139/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 140/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 141/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 142/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 143/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 144/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 145/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 146/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 147/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 148/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 149/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 150/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 151/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 152/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 153/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 154/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 155/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 156/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 157/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 158/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 159/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 160/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 161/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 162/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 163/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 164/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 165/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 166/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 167/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 168/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 169/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 170/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 171/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 172/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 173/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 174/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 175/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 176/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 177/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 178/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 179/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 180/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 181/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 182/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 183/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 184/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 185/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 186/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 187/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 188/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 189/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 190/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 191/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 192/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 193/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 194/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 195/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 196/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 197/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 198/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 199/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 200/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 201/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 202/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 203/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 204/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 205/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 206/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 207/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 208/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 209/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 210/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 211/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 212/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 213/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 214/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 215/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 216/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 217/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 218/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 219/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 220/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 221/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 222/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 223/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 224/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 225/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 226/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 227/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 228/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 229/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 230/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 231/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 232/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 233/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 234/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 235/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 236/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 237/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 238/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 239/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 240/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 241/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 242/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 243/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 244/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 245/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 246/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 247/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 248/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 249/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 250/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 251/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 252/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 253/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 254/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 255/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 256/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 257/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 258/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 259/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 260/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 261/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 262/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 263/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 264/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 265/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 266/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 267/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 268/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 269/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 270/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 271/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 272/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 273/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 274/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 275/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 276/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 277/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 278/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 279/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 280/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 281/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 282/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 283/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 284/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 285/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 286/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 287/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 288/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 289/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 290/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 291/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 292/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 293/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 294/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 295/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 296/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 297/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 298/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 299/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 300/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 301/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 302/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 303/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 304/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 305/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 306/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 307/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 308/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 309/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 310/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 311/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 312/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 313/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 314/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 315/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 316/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 317/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 318/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 319/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 320/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 321/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 322/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 323/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 324/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 325/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 326/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 327/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 328/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 329/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 330/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 331/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 332/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 333/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 334/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 335/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 336/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 337/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 338/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 339/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 340/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 341/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 342/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 343/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 344/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 345/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 346/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 347/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 348/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 349/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 350/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 351/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 352/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 353/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 354/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 355/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 356/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 357/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 358/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 359/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 360/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 361/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 362/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 363/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 364/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 365/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 366/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 367/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 368/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 369/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 370/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 371/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 372/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 373/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 374/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 375/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 376/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 377/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 378/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 379/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 380/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 381/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 382/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 383/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 384/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 385/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 386/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 387/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 388/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 389/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 390/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 391/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 392/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 393/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 394/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 395/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 396/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 397/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 398/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 399/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 400/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 401/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 402/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 403/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 404/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 405/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 406/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 407/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 408/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 409/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 410/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 411/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 412/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 413/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 414/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 415/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 416/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 417/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 418/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 419/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 420/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 421/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 422/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 423/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 424/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 425/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 426/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 427/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 428/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 429/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 430/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 431/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 432/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 433/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 434/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 435/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 436/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 437/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 438/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 439/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 440/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 441/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 442/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 443/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 444/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 445/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 446/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 447/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 448/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 449/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 450/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 451/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 452/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 453/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 454/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 455/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 456/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 457/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 458/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 459/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 460/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 461/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 462/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 463/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 464/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 465/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 466/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 467/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 468/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 469/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 470/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 471/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 472/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 473/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 474/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 475/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 476/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 477/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 478/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 479/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 480/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 481/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 482/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 483/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 484/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 485/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 486/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 487/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 488/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 489/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 490/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 491/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 492/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 493/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 494/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 495/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 496/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 497/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 498/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 499/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 500/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0098 - val_mse: 0.0098

# %%
ignore = 0

# Create a figure for loss visualization
plt.figure(figsize=(21, 4))

# Plot training and validation loss
plt.plot(history['loss'][ignore:], label='Training loss', alpha=.2, color='#1f77b4')
plt.plot(history['val_loss'][ignore:], label='Validation loss', alpha=.8, color='#1f77b4')
plt.title('Loss')
plt.legend()
plt.grid(alpha=.3)

# Create a figure for Mean Squared Error visualization
plt.figure(figsize=(21, 4))

# Plot training and validation MSE
plt.plot(history['mse'][ignore:], label='Training MSE', alpha=.2, color='#1f77b4')
plt.plot(history['val_mse'][ignore:], label='Validation MSE', alpha=.8, color='#1f77b4')
plt.title('Mean Squared Error')
plt.legend()
plt.grid(alpha=.3)

# Display the plots
plt.show()

# %%
metadata = evaluate_and_plot_model(
    model,
    X_val,
    y_val,
    X_test,
    y_test,
    metadata,
    history=history,
    patience=0,
    model_name='Baseline',
    color='#1f77b4',
    plot_baseline=False
)

final_val_mse = round(history['val_mse'][-1], 4)
model_filename = f'Feedforward_{final_val_mse}.keras'
model.save(model_filename)

plt.figure(figsize=(10, 5))
plt.plot(history['val_mse'], color='#1f77b4', label="Baseline")
plt.title("Mean Squared Error (Validation)", fontsize=14, fontweight='bold')
plt.xlabel("Epochs", fontsize=12)
plt.ylabel("MSE", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.xlim(0, len(history['val_mse']))
plt.ylim(min(history['val_mse']) * 0.9, max(history['val_mse']) * 1.1)
plt.legend()
plt.show()
# Out:
# VALIDATION MSE

# %%
# Evaluate and plot performance on the training data
print('Train Performance')
plot_residuals(model, X_train.copy(), y_train.copy())

# Evaluate and plot performance on the validation data
print('Validation Performance')
plot_residuals(model, X_val.copy(), y_val.copy())

# Evaluate and plot performance on the test data
print('Test Performance')
plot_residuals(model, X_test.copy(), y_test.copy())
# Out:
# Train Performance
# MSE: 0.0070
# Validation Performance
# MSE: 0.0098
# Test Performance
# MSE: 0.0077
